# %% [markdown]
# #                                      LEARN PANDAS
# ##                                                     NUMPY

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("netflix_titles_2021.csv")

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.sample(5) #select random 5 rows
# Out:
#      show_id     type                   title         director  \
# 315     s316    Movie        Ije: The Journey  Chineze Anyaene
# 76       s77  TV Show         Yowamushi Pedal              NaN
# 7817   s7818    Movie  Rachel Getting Married   Jonathan Demme
# 4346   s4347    Movie            Power Paandi          Dhanush
# 2726   s2727    Movie        Hasee Toh Phasee     Vinil Mathew
#
#                                                    cast  \
# 315   Genevieve Nnaji, Omotola Jalade-Ekeinde, Odaly...
# 76    Daiki Yamashita, Kohsuke Toriumi, Jun Fukushim...
# 7817  Anne Hathaway, Rosemarie DeWitt, Debra Winger,...
# 4346  Rajkiran, Dhanush, Prasanna, Chaya Singh, Reva...
# 2726  Sidharth Malhotra, Parineeti Chopra, Adah Shar...
#
#                      country          date_added  release_year rating  \
# 315   United States, Nigeria      August 3, 2021          2010  TV-MA
# 76                     Japan  September 14, 2021          2013  TV-14
# ...

# %%
df.shape #shows number of rows and column
# Out:
# (8807, 12)

# %%
df.columns #display column names
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info() #this function is used to obtain the knowledge of datatype of each and every column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe() #to obtain descriptive statistics
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum() #to find total number of null values
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum() #to find duplicate values
# Out:
# 0

# %%
df.loc[156:201] #to display range of rows
# Out:
#     show_id     type                                      title  \
# 156    s157    Movie                          Letters to Juliet
# 157    s158    Movie                                   Level 16
# 158    s159    Movie                    Love Don't Cost a Thing
# 159    s160    Movie                             Love in a Puff
# 160    s161  TV Show                                  Major Dad
# 161    s162    Movie                              Mars Attacks!
# 162    s163    Movie                                   Marshall
# 163    s164    Movie                         My Boss's Daughter
# 164    s165    Movie                                Mystery Men
# 165    s166  TV Show                                   Oldsters
# 166    s167    Movie                Once Upon a Time in America
# 167    s168    Movie                              Open Season 2
# 168    s169    Movie                              Osmosis Jones
# 169    s170    Movie                                   Poseidon
# ...

# %%
df.value_counts()
# Out:
# show_id  type   title                director             cast                                                                                                                                                                           country                                                 date_added          release_year  rating  duration  listed_in                                         description
# s10      Movie  The Starling         Theodore Melfi       Melissa McCarthy, Chris O'Dowd, Kevin Kline, Timothy Olyphant, Daveed Diggs, Skyler Gisondo, Laura Harrier, Rosalind Chao, Kimberly Quinn, Loretta Devine, Ravi Kapoor         United States                                           September 24, 2021  2021          PG-13   104 min   Comedies, Dramas                                  A woman adjusting to life after a loss contends with a feisty bird that's taken over her garden — and a husband who's struggling to find a way forward.     1
# ...

# %%
df["country"].value_counts() #
# Out:
# United States                                                                  2818
# India                                                                           972
# United Kingdom                                                                  419
# Japan                                                                           245
# South Korea                                                                     199
#                                                                                ...
# United Kingdom, Czech Republic, Germany, United States                            1
# United States, Australia, Mexico                                                  1
# Denmark, France, Belgium, Italy, Netherlands, United States, United Kingdom       1
# United States, Italy, United Kingdom, Liechtenstein                               1
# Canada, Nigeria, United States                                                    1
# Name: country, Length: 748, dtype: int64

# %%
df.groupby(by=["country","type"]).size()
# Out:
# country                                              type
# , France, Algeria                                    Movie       1
# , South Korea                                        TV Show     1
# Argentina                                            Movie      38
#                                                      TV Show    18
# Argentina, Brazil, France, Poland, Germany, Denmark  Movie       1
#                                                                 ..
# Venezuela                                            Movie       1
# Venezuela, Colombia                                  Movie       1
# Vietnam                                              Movie       7
# West Germany                                         Movie       1
# Zimbabwe                                             Movie       1
# Length: 847, dtype: int64

# %%
df.sort_values(by='show_id',inplace=True,ascending=False)
df.head()
# Out:
#     show_id     type                                  title  \
# 998    s999    Movie                   Searching For Sheela
# 997    s998  TV Show  Life in Color with David Attenborough
# 996    s997    Movie                             HOMUNCULUS
# 995    s996    Movie                              Vizontele
# 994    s995    Movie                  This Lady Called Life
#
#                              director  \
# 998                               NaN
# 997                               NaN
# 996                   Takashi Shimizu
# 995  Yılmaz Erdoğan, Ömer Faruk Sorak
# 994                      Kayode Kasum
#
#                                                   cast  \
# 998                                    Ma Anand Sheela
# 997                                 David Attenborough
# 996  Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...
# 995  Yılmaz Erdoğan, Demet Akbağ, Altan Erkekli, Ce...
# 994  Bisola Aiyeola, Efa Iwara, Molawa Onajobi, Tin...
#
# ...
